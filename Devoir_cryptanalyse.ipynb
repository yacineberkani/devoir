# %% [markdown]
# #  Permutation de l'alphabet avec le tableau 3x9
#
# **À partir de mon Nom et Prénom "BERKANI Yacine", nous suivrons la règle du tableau 3x9 pour obtenir une permutation :**
#
#   - Création de la liste sans doublons : Conserve les lettres uniques de "BERKANI Yacine", ce qui donne "BERKANIYC".
#   - Ajout des lettres restantes : Complète avec les lettres manquantes de l'alphabet en ordre alphabétique après "BERKANIYC".
#
# **En appliquant ces étapes, nous remplirons un tableau de 3 lignes et 9 colonnes, puis lirons colonne par colonne pour obtenir la permutation de l'alphabet.**

# %%
def generer_permutation_depuis_nom(nom):
    nom = nom.upper()
    caracteres_uniques = []
    for char in nom:
        if char not in caracteres_uniques and 'A' <= char <= 'Z':
            caracteres_uniques.append(char)
    alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    for char in alphabet:
        if char not in caracteres_uniques:
            caracteres_uniques.append(char)
    tableau = [caracteres_uniques[i:i+9] for i in range(0, len(caracteres_uniques), 9)]
    print("tableau 3x9 :", tableau, "\n")
    permutation = []
    for col in range(9):
        for row in range(3):
            if col < len(tableau[row]):
                permutation.append(tableau[row][col])

    return permutation

nom = "BERKANI Yacine"
permutation = generer_permutation_depuis_nom(nom)
print("Permutation de l'alphabet:", permutation)
# Out:
# tableau 3x9 : [['B', 'E', 'R', 'K', 'A', 'N', 'I', 'Y', 'C'], ['D', 'F', 'G', 'H', 'J', 'L', 'M', 'O', 'P'], ['Q', 'S', 'T', 'U', 'V', 'W', 'X', 'Z']]
#
# Permutation de l'alphabet: ['B', 'D', 'Q', 'E', 'F', 'S', 'R', 'G', 'T', 'K', 'H', 'U', 'A', 'J', 'V', 'N', 'L', 'W', 'I', 'M', 'X', 'Y', 'O', 'Z', 'C', 'P']

# %%
permutation_final = ''.join(permutation)
print("BERKNAI Yacine permutation de l'alphabet avec la règle du tableau 3x9  ",  permutation_final)
# Out:
# BERKNAI Yacine permutation de l'alphabet avec la règle du tableau 3x9   BDQEFSRGTKHUAJVNLWIMXYOZCP

# %% [markdown]
# # Chiffrement du texte
# En appliquant la permutation d’alphabet générée à l’étape précédente, chaque lettre de **[CSIA.txt](https://github.com/yacineberkani/devoir/blob/main/CSIA.txt)** sera remplacée par son équivalent chiffré. Cela formera le texte chiffré.
#
#
#
# # **Voici le fichier après le chiffrement [CSIA_chiffre.txt](https://github.com/yacineberkani/devoir/blob/main/CSIA_chiffre.txt)**

# %%
def creer_dictionnaire_substitution(permutation):
    
    alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    return {alphabet[i]: permutation[i] for i in range(len(alphabet))}

def chiffrer_texte(texte_entree, dictionnaire_substitution):
    # 
    texte_chiffre = ""
    for char in texte_entree.upper():
        if char in dictionnaire_substitution:
            texte_chiffre += dictionnaire_substitution[char]
        else:
            texte_chiffre += char  
    return texte_chiffre


with open("CSIA.txt", "r") as fichier:
    texte_original = fichier.read()


dictionnaire_substitution = creer_dictionnaire_substitution(permutation)
texte_chiffre = chiffrer_texte(texte_original, dictionnaire_substitution)


print("Texte chiffré:", texte_chiffre)
with open("CSIA_chiffre.txt", "w") as fichier:
    fichier.write(texte_chiffre)
# Out:
# Texte chiffré: TB FM QCDFWIÉQXWTMÉ : 8 QBI E’XIBRF NWTJQTNBXZ
#
#
# TJMFUUTRFJQF FM QCDFWIÉQXWTMÉ : 8 QBI E'XIBRF.
# 24 KXTUUFM 2020
# U’TJMFUUTRFJQF BWMTSTQTFUUF (TB) FIM NFWÇXF NBW UB NUXNBWM EFI INÉQTBUTIMFI QVAAF XJF BYBJQÉF MWÈI NWVSTMBDUF À JVMWF IVQTÉMÉ, NFWAFMMBJM EF NWÉETWF JVI DFIVTJI FM BTJIT E’C WÉNVJEWF BYFQ BJMTQTNBMTVJ.
# FJ ABMTÈWF EF QCDFWIÉQXWTMÉ, UB ITANUF EFIQWTNMTVJ EF UB ITMXBMTVJ BQMXFUUF EFI AFJBQFI EBJI UF QCDFWFINBQF IXSSTM À QVANWFJEWF U’TJMÉWÊM LXF U’TJEXIMWTF NVWMF À U’TJMFUUTRFJQF BWMTSTQTFUUF (TB). IXW UF NBNTFW, U’TB, BYFQ IB QBNBQTMÉ À QVANWFJEWF FM BJBUCIFW XJ QVJMFZMF EVJJÉ, NFXM QVJMWTDXFW À C EÉMFQMFW EFI BJVABUTFI VX EFI QVANVWMFAFJMI TJGBDTMXFUI, WÉYÉUBMFXWI E’BMMBLXFI FM BTJIT, À WFJSVWQFW UFI VXMTUI EF NWVMFQMTVJ, EÉMFQMTVJ, WÉNVJIF FM WFAÉETBMTVJ : BXRAFJMBMTVJ EX MBXZ EF EÉMFQMTVJ, EÉMFQMTVJ BX NUXI MÔM EFI BMMBLXFI, BAÉUTVWBMTVJ EF UB QBNBQTMÉ E’BEBNMBMTVJ BXZ ÉYVUXMTVJI NFWABJFJMFI EFI IT.
# 1- U’TB TJMÉRWÉF BXZ ÉLXTNFAFJMI FM BNNUTQBMTVJI EF QCDFWIÉQXWTMÉ EF U’TJSWBIMWXQMXWF
# EFI MFQGJVUVRTFI E’TJMFUUTRFJQF BWMTSTQTFUUF IVJM EÉKÀ TJMÉRWÉFI EBJI EFI VXMTUI QVAAF UFI BJMT-YTWXI, UFI IVUXMTVJI FEW (FJENVTJM EFMFQMTVJ BJE WFINVJIF), UFI NBIIFWFUUFI ABTU VX OFD, UFI STWFOBUUI, U’TBA, UFI QBID, UFI IVUXMTVJI EUN…, IVTM EFI ÉLXTNFAFJMI LXT WÉBRTIIFJM BXMVABMTLXFAFJM BXZ BMMBLXFI FJ STUMWBJM UF MWBSTQ ABUTQTFXZ. UB NUXNBWM EFI ÉETMFXWI UF SVJM C QVANWTI FJ XMTUTIBJM QFWMBTJFI MFQGJVUVRTFI BYBJQÉFI MFUUFI LXF UF EFFN UFBWJTJR (RVVRUF U’B TJMÉRWÉ EFNXTI 2015 NVXW STUMWFW UFI INBAI EBJI RABTU).
# 2- U’TB TJMÉRWÉF EBJI UFI IVJEFI WÉIFBXZ FM BXMWFI TJMWXITVJ EFMFQMTVJ ICIMFAI (TEI)
# EF JVADWFXIFI IVJEFI TJMÈRWFJM EFI MFQGJVUVRTFI E’TB, FJ QVANUÉAFJM EF UFXW AVMFXW EF EÉMFQMTVJ. UB NUXNBWM EF QFI ICIMÈAFI BNNWFJJFJM UF QVANVWMFAFJM « JVWABU » EF U’TJSWBIMWXQMXWF FM MVXMF EÉYTBMTVJ FIM WFAVJMÉF QVAAF XJ ITRJF E’XJ WTILXF QCDFW.UFI BUFWMFI WFAVJMÉFI IVJM FZNUVTMÉFI NBW EFI BJBUCIMFI, MCNTLXFAFJM BX IFTJ E’XJ IVQ, BYFQ XJ MBXZ EF SBXZ NVITMTSI JVJ JÉRUTRFBDUF. U’BKVXM EF QFI MFQGJVUVRTFI EBJI XJF TJSWBIMWXQMXWF BXRAFJMFW UB QGBWRF EF MWBYBTU, MVXM FJ NFWAFMMBJM EF EÉMFQMFW NUXI E’BMMBLXFI, VX EF UFI EÉMFQMFW NUXI MÔM. XJ EFI FJKFXZ FIM EVJQ EF ATFXZ TJMÉRWFW QFI VXMTUI. QVJQWÈMFAFJM, UB NFWMTJFJQF EF QFI MFQGJVUVRTFI E’TB FIM E’BXMBJM NUXI RWBJEF LX’FUUFI IVJM EÉNUVCÉFI EBJI UFI FJYTWVJJFAFJMI VÙ UF MWBSTQ FIM WFUBMTYFAFJM EÉMFWATJTIMF, MFUI LXF EBJI UFI FJYTWVJJFAFJMI TJEXIMWTFUI.
# 3- U’TB NVXW EÉMFQMFW UFI QVANVWMFAFJMI BJVWABXZ EBJI XJ IVQ
# EBJI QF QBI E’XIBRF, U’TB FIM XMTUTIÉF FJ NBWBUUÈUF VX FJ QVANUÉAFJM EF UB EÉMFQMTVJ MFANI WÉFU FSSFQMXÉF NBW FZFANUF EBJI XJ ITFA : UF ICIMÈAF BNNWFJE EX QVANVWMFAFJM IMBJEBWE EF U’TJSWBIMWXQMXWF VX EFI XMTUTIBMFXWI FM AFIXWF EFI ÉQBWMI NBW WBNNVWM À QF QVANVWMFAFJM.
# À UB ETSSÉWFJQF EFI IVJEFI LXT IVJM NUBQÉFI À XJ FJEWVTM NWÉQTI EF U’TJSWBIMWXQMXWF, U’TJSVWABMTVJ WÉQVUMÉF NBW U’VXMTU NFXM-ÊMWF FZMWÊAFAFJM GÉMÉWVRÈJF FM NWVYFJTW EF AXUMTNUFI IVXWQFI, QF LXT BQQWVTM MWÈI IFJITDUFAFJM UF JTYFBX EF ETSSTQXUMÉ. EF SBTM, QFI MFQGJVUVRTFI NBWBTIIFJM BXKVXWE’GXT NUXI NFWMTJFJMFI FJ QVANUÉAFJM EFI VXMTUI QUBIITLXFI NVXW EFI FJYTWVJJFAFJMI WFUBMTYFAFJM IMBDUFI FM EÉMFWATJTIMFI.
# 4- U’TB NVXW U’TJYFIMTRBMTVJ EFI BUFWMFI FM UB WFQGFWQGF NWVBQMTYF EF QVANWVATIITVJ (GXJMTJR) EBJI XJ IVQ
# UFI BJBUCIMFI E’XJ IVQ NBWMFJM MCNTLXFAFJM E’XJF BUFWMF ÉABJBJM E’XJ ITFA VX E’XJ BXMWF VXMTU NVXW FJIXTMF FJ EÉMFWATJFW UB QWTMTQTMÉ, U’ÉMFJEXF, U’XWRFJQF BTJIT LXF UFI ÉUÉAFJMI MFQGJTLXFI NFWAFMMBJM EF IMVNNFW UFI BMMBLXFI FM E’C WFAÉETFW. TUI BQQÈEFJM NVXW QFUB À XJ NXTMI EF EVJJÉFI (EBMB UBHF) VÙ IVJM IMVQHÉI UFI UVRI, EFI AÉMBEVJJÉFI EF MWBSTQ VX BXMWFI TJSVWABMTVJI. EF NUXI QF NXTMI EF EVJJÉFI NFXM ÊMWF FZNUVTMÉ NVXW WFQGFWQGFW EFI MWBQFI E’BXMWFI BMMBLXFI LXT J’BXWBTFJM NBI ÉMÉ EÉMFQMÉFI FJ MFANI WÉFU. QFMMF BQMTYTMÉ I’BNNXTF À UB SVTI IXW EF U’FZNFWMTIF GXABTJF FM IXW EFI VXMTUI (WFQGFWQGFI E’VDIFWYBDUFI, QVWWÉUBMTVJ E’ÉYÉJFAFJMI, FMQ.). U’TJMÉRWBMTVJ E’TB EBJI QFI VXMTUI NFWAFM E’BIITIMFW UFI FZNFWMI NVXW LX’TUI BQQÈEFJM NUXI WBNTEFAFJM FM SBQTUFAFJM À UB DVJJF TJSVWABMTVJ FM NVXW LX’TUI IVTFJM RXTEÉI EBJI UFXWI WFQGFWQGFI.
# 5- U’TB BNNUTLXÉF À UB WÉNVJIF IXW TJQTEFJM
# NVXW WÉNVJEWF BXZ TJQTEFJMI EF QCDFWIÉQXWTMÉ, UFI ÉLXTNFI QFWM VX QITWM FSSFQMXFJM EF JVADWFXIFI MÂQGFI LXT NFXYFJM FJ NBWMTF ÊMWF BXMVABMTIÉFI : WÉTJIMBUUBMTVJ E’BJMT-YTWXI, YÉWTSTQBMTVJ EF QUÉI EF WFRTIMWF, AVETSTQBMTVJ EF WÈRUFI EBJI UFI STWFOBUUI, FMQ.UFI NUBMFI-SVWAFI EF WÉNVJIF BXZ TJQTEFJMI (IFQXWTMC VWQGFIMWBMTVJ BJE BXMVABMFE WFINVJIF – IVBW VX IFQXWTMC TJQTEFJM WFINVJIF NUBMSVWA – ITWN) NWVNVIFJM EFI IQÉJBWTVI EF WÉNVJIF, BXMVABMTLXFI VX IFAT-BXMVABMTLXFI, BSTJ EF SBQTUTMFW UB IÉUFQMTVJ, U’FZÉQXMTVJ FM U’FJQGBTJFAFJM EFI MÂQGFI. QFWMBTJFI QVAAFJQFJM ÉRBUFAFJM À TJMÉRWFW EFI MFQGJVUVRTFI E’TB BSTJ E’BIITIMFW NUXI FSSTQBQFAFJM UFI TJMFWYFJBJMI EBJI UB IÉUFQMTVJ EFI BQMTVJI À FSSFQMXFW FM E’BXRAFJMFW U’BXMVABMTIBMTVJ.
# 6- U’TB BNNUTLXÉF BX WFJIFTRJFAFJM IXW UB AFJBQF (MGWFBM TJMFUUTRFJQF)
# UF WFJIFTRJFAFJM IXW UB AFJBQF QVJITIMF À QVUUFQMFW (MCNTLXFAFJM IXW UF OFD VX EBWHOFD), XJ FJIFADUF E’TJSVWABMTVJI IXW UB AFJBQF FM À UFI WFJEWF VNÉWBMTVJJFUUFI : LXFUI RWVXNFI E’BMMBLXBJMI IVJM BQMTSI FM NVXW SBTWF LXVT, BYFQ LXFUI AVEFI VNÉWBMVTWFI, FZNUVTMBJM LXFUUFI YXUJÉWBDTUTMÉI, À NBWMTW EF LXFUI IFWYFXWI OFD QVANWVATI EF QVAABJE & QVJMWVU… NUXMÔM LXF EF IF DBMMWF QVJMWF XJ FJJFAT TJYTITDUF, TU I’BRTM E’VDMFJTW EFI WFJIFTRJFAFJMI IXW UXT NVXW ATFXZ UF QVJMWFW. XJ EFI NWVDUÈAFI EX WFJIFTRJFAFJM IXW UB AFJBQF WÉITEF EBJI UB QBNBQTMÉ À SVXWJTW EFI TJSVWABMTVJI NFWMTJFJMFI EF ABJTÈWF IMWXQMXWÉF.
# 7- U’TB BNNUTLXÉF À UB RFIMTVJ EFI YXUJÉWBDTUTMÉI
# UB RFIMTVJ EFI YXUJÉWBDTUTMÉI FIM EFYFJXF XJ NVTJM EF MFJITVJ NVXW UFI ÉLXTNFI VNÉWBMTVJJFUUFI, EX SBTM EF U’BXRAFJMBMTVJ QVJIMBJMF EX JVADWF EF SBTUUFI QVJJXFI, EFI ETSSTQXUMÉI À ÉYBUXFW UFI WTILXFI WÉFUI TJEXTMI FM À NWTVWTIFW FM BXMVABMTIFW UF EÉNUVTFAFJM EFI NBMQGI. FJ FSSFM, IXW UFI ATUUTFWI EF YXUJÉWBDTUTMÉI NXDUTÉFI MVXI UFI BJI, IFXUF XJF SWBQMTVJ FIM WÉFUUFAFJM XMTUTIÉF NBW UFI BMMBLXBJMI. EF NUXI, QFWMBTJI ICIMÈAFI FJ IVJM NWVMÉRÉI NBW EFI EÉSFJIFI NÉWTAÉMWTLXFI.
# QFMMF QVANUFZTMÉ TJQTMF UFI SVXWJTIIFXWI E’VXMTUI EF RFIMTVJ EFI YXUJÉWBDTUTMÉI À TJMÉRWFW EFI MFQGJVUVRTFI E’TB EBJI UFXWI IVUXMTVJI. U’VDKFQMTS EF U’TB BNNUTLXÉF À UB RFIMTVJ EFI YXUJÉWBDTUTMÉI FIM E’BAÉUTVWFW UB EÉQVXYFWMF EFI ÉLXTNFAFJMI EÉNUVCÉI, UF IQBJ EFI YXUJÉWBDTUTMÉI, UB EÉMFWATJBMTVJ EFI WTILXFI BIIVQTÉI FJ UTFJ BYFQ U’TJMFUUTRFJQF IXW UB AFJBQF, UB NWTVWTIBMTVJ FM UF EÉNUVTFAFJM EFI NBMQGI.
# 8- U’TB BNNUTLXÉF BXZ MFIMI E’TJMWXITVJI
# EBJI UB AÊAF YFTJF, FM DTFJ LX’TU I’BRTIIF À QF IMBEF NUXI E’XJF YTITVJ VX EF NWVMVMCNFI LXF EF WÉBUTMÉ, EFI MWBYBXZ ÉABJBJM EF UBDVWBMVTWFI XJTYFWITMBTWFI, E’BRFJQFI RVXYFWJFAFJMBUFI, E’FJMWFNWTIFI ÉMBDUTFI VX EF IMBWM-XNI, YTIFJM À BNNUTLXFW U’TB BXZ MFIMI E’TJMWXITVJI.
# QFI MFIMI JÉQFIITMFJM EF MWVXYFW EFI YXUJÉWBDTUTMÉI NBWAT EF AXUMTNUFI NVIITDUFI IXW EF JVADWFXZ ICIMÈAFI, NXTI E’FZNUVTMFW QFI YXUJÉWBDTUTMÉI NBW ETSSÉWFJMFI MFQGJTLXFI. U’BWDWF EFI QGVTZ NVIITDUFI EFYTFJM WBNTEFAFJM MWVN TANVWMBJM NVXW ÊMWF RÉWÉ NBW XJ GXABTJ VX AÊAF NBWQVXWX BXMVABMTLXFAFJM. NBW BTUUFXWI, U’BJBUCIF EF UB NWBMTLXF EFI MFIMFXWI GXABTJI WÉYÈUF LX’TUI VJM MFJEBJQF À NWTYTUÉRTFW UF NBWQVXWI EF U’BWDWF FJ NWVSVJEFXW NUXMÔM LX’FJ UBWRFXW. IT MFQGJVUVRTFI E’TB QVJIMTMXFJM XJ AVCFJ EF QVANFJIFW UFI UTATMFI FM QVJMWBTJMFI EFI ETINVITMTSI BQMXFUI, NUXITFXWI NVTJMI E’BMMFJMTVJ EVTYFJM ÊMWF NWTI FJ QVANMF. U’TB VX NUXMÔM UF ABQGTJF UFBWJTJR B IXWMVXM SBTM IFI NWFXYFI EBJI UB EÉMFQMTVJ EF SWBXEFI, XJ EVABTJF QVJJFZF À UB QCDFWIÉQXWTMÉ. IFI DVJI WÉIXUMBMI I’FZNUTLXFJM NBW UF SBTM LXF U’VJ MWBYBTUUF EFNXTI XJ QFWMBTJ MFANI IXW EFI EVJJÉFI JVWAÉFI. BXIIT, FUUF JF NFXM ÊMWF YXF LXF QVAAF XJ QVANUÉAFJM BURVWTMGATLXF BXZ VXMTUI FZTIMBJMI.IT U’TB AVETSTF UF JTYFBX E’FZNFWMTIF JÉQFIIBTWF À QFWMBTJFI BQMTYTMÉI EF QCDFWIÉQXWTMÉ RWÂQF U’BXMVABMTIBMTVJ EFI MÂQGFI À SBTDUF YBUFXW BKVXMÉF, TU J’FJ WFIMF NBI AVTJI LXF NVXW UF AVAFJM U’TB JF ETATJXF NBI UF DFIVTJ RUVDBU E’FZNFWMTIF GXABTJF. FJ FSSFM UFI ÉLXTNFI EVTYFJM BJBUCIFW NUXI E’ÉYÈJFAFJMI FM EF QVANVWMFAFJMI IXINFQMI À NBWMTW EF WFAVJMÉFI LXT ETSSTQTUFI À TJMFWNWÉMFW FM LXT JÉQFIITMFJM NBW QVJIÉLXFJM EFI FZNFWMTIFI EF GBXM JTYFBX. U’TB QVJJBÎM ÉRBUFAFJM QFWMBTJFI UTATMFI AVWBUFI YVTWF UÉRBUFI QBW FUUF NFXM NBWSVTI NWFJEWF EFI EÉQTITVJI ETIQXMBDUFI E’XJ NVTJM EF YXF ÉMGTLXF FM FZNUVTMF IVXYFJM EFI EVJJÉFI À QBWBQMÈWF NFWIVJJFU.
# FM IXWMVXM… UFI ICIMÈAFI EF EÉSFJIF À DBIF E’TB IVJM FXZ-AÊAFI YXUJÉWBDUFI BXZ UFXWWFI LXF UFI BMMBLXBJMI AFMMFJM FJ NUBQF NVXW UFI QVJMVXWJFW.
# UFI BMMBLXBJMI XMTUTIFJM BXIIT EFI MFQGJVUVRTFI E’TB NVXW BXRAFJMFW UFXW NVMFJMTFU EF JXTIBJQF À AVTJEWF QVÛM : NVXW IÉUFQMTVJJFW UFXWI QTDUFI, VNMTATIFW UFXWI QBNBQTMÉI E’TJMWXITVJ (FZ : NGTIGTJR TJMFUUTRFJM), EÉMFWATJFW UFI AFTUUFXWFI SBTUUFI À FZNUVTMFW (FZ : IQBJ EF NBRFI OFD TJMFUUTRFJM), NBIIFW BXMBJM LXF NVIITDUF IVXI UF WBEBW EFI ICIMÈAFI EF EÉMFQMTVJ, FMQ. NBW IB QBNBQTMÉ À MWBTMFW EF RWBJEI YVUXAFI EF EVJJÉFI, U’TB NFXM ÊMWF YXF QVAAF XJ BUUTÉ BX IFWYTQF EFI EÉSFJIFXWI EX QCDFWFINBQF, FJ NBWMTQXUTFW NVXW EÉMFQMFW EFI AFJBQFI TJQVJJXFI À QVJETMTVJ MVXMFSVTI E’ÊMWF FJ QBNBQTMÉ EF MWBTMFW UFI SBXZ NVITMTSI (FM UFI SBXZ JÉRBMTSI ?). ABTI FUUF NFXM BXIIT ÊMWF ATIF À NWVSTM NBW UFI BIIBTUUBJMI FM UFXW NFWAFMMWF EF EÉYFUVNNFW EFI BMMBLXFI TJMFUUTRFJMFI QBNBDUFI EF I’BEBNMFW FJ MFANI WÉFU BXZ WÉBQMTVJI EÉSFJITYFI.
# UB DUVQHQGBTJ, U’TB VX UF ABQGTJF UFBWJTJR IFWVJM-TUI UFI WÉNVJIFI LXF JVXI BMMFJEVJI MBJM ?
# UÀ FJQVWF, TU SBXM SBTWF UB NBWM EFI QGVIFI. QFI MFQGJVUVRTFI JF IFWVJM KBABTI EFI WÉNVJIFI BXZ LXFIMTVJI LX’FUUFI J’BEWFIIFJM NBI. FUUFI NFWAFMMWVJM YWBTIFADUBDUFAFJM EF SBTWF BYBJQFW UFI EVABTJFI EF WFQGFWQGF, EF QWÉFW EF JVXYFUUFI VSSWFI, E’VSSWTW XJF BIITIMBJQF BXZ NBWMTFI NWFJBJMFI, ABTI BXWVJM FJQVWF DTFJ EFI ETSSTQXUMÉI À IÉQXWTIFW QF LXF JVXI JF ABÎMWTIVJI NBI MVXKVXWI.

# %% [markdown]
# # Analyse fréquentielle du texte chiffré
# Il s’agit de compter les occurrences de chaque lettre dans le texte chiffré et de les comparer aux fréquences standards en français pour estimer les substitutions probables.

# %%
from collections import Counter

def analyse_frequence(texte):
    compteur = Counter([char for char in texte.upper() if 'A' <= char <= 'Z'])
    total = sum(compteur.values())


    frequence = {char: count / total * 100 for char, count in compteur.items()}

    frequence_trie = dict(sorted(frequence.items(), key=lambda item: item[1], reverse=True))

    return frequence_trie


frequence_lettres = analyse_frequence(texte_chiffre)
print("Fréquence des lettres:", frequence_lettres)
# Out:
# Fréquence des lettres: {'F': 15.1994851994852, 'I': 9.523809523809524, 'M': 8.996138996138995, 'T': 7.644787644787645, 'J': 7.5933075933075935, 'B': 6.885456885456885, 'W': 6.537966537966539, 'U': 5.817245817245817, 'X': 5.418275418275418, 'V': 5.096525096525097, 'E': 4.285714285714286, 'Q': 3.7966537966537968, 'N': 3.423423423423423, 'A': 2.7155727155727156, 'S': 1.2226512226512225, 'R': 1.0810810810810811, 'L': 0.9652509652509652, 'Y': 0.9523809523809524, 'D': 0.8622908622908623, 'G': 0.6435006435006435, 'Z': 0.6306306306306306, 'C': 0.45045045045045046, 'K': 0.11583011583011582, 'O': 0.09009009009009009, 'H': 0.05148005148005148}

# %% [markdown]
# # Déchiffrement
# À partir de l’analyse fréquentielle, en remplaçant les lettres dans le texte chiffré par les lettres probables, nous retrouverons progressivement le texte en clair.
#
#
#
#
#
#
#
# # **Voici le fichier après le déchiffrement [CSIA_dechiffre.txt](https://github.com/yacineberkani/devoir/blob/main/CSIA_dechiffre.txt)**

# %%
def dechiffrer_texte(texte_chiffre, dictionnaire_substitution_inverse):
    texte_dechiffre = ""
    for char in texte_chiffre.upper():
        if char in dictionnaire_substitution_inverse:
            texte_dechiffre += dictionnaire_substitution_inverse[char]
        else:
            texte_dechiffre += char 
    return texte_dechiffre


dictionnaire_substitution_inverse = {v: k for k, v in dictionnaire_substitution.items()}

texte_dechiffre = dechiffrer_texte(texte_chiffre, dictionnaire_substitution_inverse)

print("Texte déchiffré:", texte_dechiffre)
with open("CSIA_dechiffre.txt", "w") as fichier:
    fichier.write(texte_dechiffre)
# Out:
# Texte déchiffré: IA ET CYBERSÉCURITÉ : 8 CAS D’USAGE PRINCIPAUX
#
#
# INTELLIGENCE ET CYBERSÉCURITÉ : 8 CAS D'USAGE.
# 24 JUILLET 2020
# L’INTELLIGENCE ARTIFICIELLE (IA) EST PERÇUE PAR LA PLUPART DES SPÉCIALISTES COMME UNE AVANCÉE TRÈS PROFITABLE À NOTRE SOCIÉTÉ, PERMETTANT DE PRÉDIRE NOS BESOINS ET AINSI D’Y RÉPONDRE AVEC ANTICIPATION.
# EN MATIÈRE DE CYBERSÉCURITÉ, LA SIMPLE DESCRIPTION DE LA SITUATION ACTUELLE DES MENACES DANS LE CYBERESPACE SUFFIT À COMPRENDRE L’INTÉRÊT QUE L’INDUSTRIE PORTE À L’INTELLIGENCE ARTIFICIELLE (IA). SUR LE PAPIER, L’IA, AVEC SA CAPACITÉ À COMPRENDRE ET ANALYSER UN CONTEXTE DONNÉ, PEUT CONTRIBUER À Y DÉTECTER DES ANOMALIES OU DES COMPORTEMENTS INHABITUELS, RÉVÉLATEURS D’ATTAQUES ET AINSI, À RENFORCER LES OUTILS DE PROTECTION, DÉTECTION, RÉPONSE ET REMÉDIATION : AUGMENTATION DU TAUX DE DÉTECTION, DÉTECTION AU PLUS TÔT DES ATTAQUES, AMÉLIORATION DE LA CAPACITÉ D’ADAPTATION AUX ÉVOLUTIONS PERMANENTES DES SI.
# 1- L’IA INTÉGRÉE AUX ÉQUIPEMENTS ET APPLICATIONS DE CYBERSÉCURITÉ DE L’INFRASTRUCTURE
# DES TECHNOLOGIES D’INTELLIGENCE ARTIFICIELLE SONT DÉJÀ INTÉGRÉES DANS DES OUTILS COMME LES ANTI-VIRUS, LES SOLUTIONS EDR (ENDPOINT DETECTION AND RESPONSE), LES PASSERELLES MAIL OU WEB, LES FIREWALLS, L’IAM, LES CASB, LES SOLUTIONS DLP…, SOIT DES ÉQUIPEMENTS QUI RÉAGISSENT AUTOMATIQUEMENT AUX ATTAQUES EN FILTRANT LE TRAFIC MALICIEUX. LA PLUPART DES ÉDITEURS LE FONT Y COMPRIS EN UTILISANT CERTAINES TECHNOLOGIES AVANCÉES TELLES QUE LE DEEP LEARNING (GOOGLE L’A INTÉGRÉ DEPUIS 2015 POUR FILTRER LES SPAMS DANS GMAIL).
# 2- L’IA INTÉGRÉE DANS LES SONDES RÉSEAUX ET AUTRES INTRUSION DETECTION SYSTEMS (IDS)
# DE NOMBREUSES SONDES INTÈGRENT DES TECHNOLOGIES D’IA, EN COMPLÉMENT DE LEUR MOTEUR DE DÉTECTION. LA PLUPART DE CES SYSTÈMES APPRENNENT LE COMPORTEMENT « NORMAL » DE L’INFRASTRUCTURE ET TOUTE DÉVIATION EST REMONTÉE COMME UN SIGNE D’UN RISQUE CYBER.LES ALERTES REMONTÉES SONT EXPLOITÉES PAR DES ANALYSTES, TYPIQUEMENT AU SEIN D’UN SOC, AVEC UN TAUX DE FAUX POSITIFS NON NÉGLIGEABLE. L’AJOUT DE CES TECHNOLOGIES DANS UNE INFRASTRUCTURE AUGMENTER LA CHARGE DE TRAVAIL, TOUT EN PERMETTANT DE DÉTECTER PLUS D’ATTAQUES, OU DE LES DÉTECTER PLUS TÔT. UN DES ENJEUX EST DONC DE MIEUX INTÉGRER CES OUTILS. CONCRÈTEMENT, LA PERTINENCE DE CES TECHNOLOGIES D’IA EST D’AUTANT PLUS GRANDE QU’ELLES SONT DÉPLOYÉES DANS LES ENVIRONNEMENTS OÙ LE TRAFIC EST RELATIVEMENT DÉTERMINISTE, TELS QUE DANS LES ENVIRONNEMENTS INDUSTRIELS.
# 3- L’IA POUR DÉTECTER LES COMPORTEMENTS ANORMAUX DANS UN SOC
# DANS CE CAS D’USAGE, L’IA EST UTILISÉE EN PARALLÈLE OU EN COMPLÉMENT DE LA DÉTECTION TEMPS RÉEL EFFECTUÉE PAR EXEMPLE DANS UN SIEM : LE SYSTÈME APPREND DU COMPORTEMENT STANDARD DE L’INFRASTRUCTURE OU DES UTILISATEURS ET MESURE DES ÉCARTS PAR RAPPORT À CE COMPORTEMENT.
# À LA DIFFÉRENCE DES SONDES QUI SONT PLACÉES À UN ENDROIT PRÉCIS DE L’INFRASTRUCTURE, L’INFORMATION RÉCOLTÉE PAR L’OUTIL PEUT-ÊTRE EXTRÊMEMENT HÉTÉROGÈNE ET PROVENIR DE MULTIPLES SOURCES, CE QUI ACCROIT TRÈS SENSIBLEMENT LE NIVEAU DE DIFFICULTÉ. DE FAIT, CES TECHNOLOGIES PARAISSENT AUJOURD’HUI PLUS PERTINENTES EN COMPLÉMENT DES OUTILS CLASSIQUES POUR DES ENVIRONNEMENTS RELATIVEMENT STABLES ET DÉTERMINISTES.
# 4- L’IA POUR L’INVESTIGATION DES ALERTES ET LA RECHERCHE PROACTIVE DE COMPROMISSION (HUNTING) DANS UN SOC
# LES ANALYSTES D’UN SOC PARTENT TYPIQUEMENT D’UNE ALERTE ÉMANANT D’UN SIEM OU D’UN AUTRE OUTIL POUR ENSUITE EN DÉTERMINER LA CRITICITÉ, L’ÉTENDUE, L’URGENCE AINSI QUE LES ÉLÉMENTS TECHNIQUES PERMETTANT DE STOPPER LES ATTAQUES ET D’Y REMÉDIER. ILS ACCÈDENT POUR CELA À UN PUITS DE DONNÉES (DATA LAKE) OÙ SONT STOCKÉS LES LOGS, DES MÉTADONNÉES DE TRAFIC OU AUTRES INFORMATIONS. DE PLUS CE PUITS DE DONNÉES PEUT ÊTRE EXPLOITÉ POUR RECHERCHER DES TRACES D’AUTRES ATTAQUES QUI N’AURAIENT PAS ÉTÉ DÉTECTÉES EN TEMPS RÉEL. CETTE ACTIVITÉ S’APPUIE À LA FOIS SUR DE L’EXPERTISE HUMAINE ET SUR DES OUTILS (RECHERCHES D’OBSERVABLES, CORRÉLATION D’ÉVÉNEMENTS, ETC.). L’INTÉGRATION D’IA DANS CES OUTILS PERMET D’ASSISTER LES EXPERTS POUR QU’ILS ACCÈDENT PLUS RAPIDEMENT ET FACILEMENT À LA BONNE INFORMATION ET POUR QU’ILS SOIENT GUIDÉS DANS LEURS RECHERCHES.
# 5- L’IA APPLIQUÉE À LA RÉPONSE SUR INCIDENT
# POUR RÉPONDRE AUX INCIDENTS DE CYBERSÉCURITÉ, LES ÉQUIPES CERT OU CSIRT EFFECTUENT DE NOMBREUSES TÂCHES QUI PEUVENT EN PARTIE ÊTRE AUTOMATISÉES : RÉINSTALLATION D’ANTI-VIRUS, VÉRIFICATION DE CLÉS DE REGISTRE, MODIFICATION DE RÈGLES DANS LES FIREWALLS, ETC.LES PLATES-FORMES DE RÉPONSE AUX INCIDENTS (SECURITY ORCHESTRATION AND AUTOMATED RESPONSE – SOAR OU SECURITY INCIDENT RESPONSE PLATFORM – SIRP) PROPOSENT DES SCÉNARIOS DE RÉPONSE, AUTOMATIQUES OU SEMI-AUTOMATIQUES, AFIN DE FACILITER LA SÉLECTION, L’EXÉCUTION ET L’ENCHAINEMENT DES TÂCHES. CERTAINES COMMENCENT ÉGALEMENT À INTÉGRER DES TECHNOLOGIES D’IA AFIN D’ASSISTER PLUS EFFICACEMENT LES INTERVENANTS DANS LA SÉLECTION DES ACTIONS À EFFECTUER ET D’AUGMENTER L’AUTOMATISATION.
# 6- L’IA APPLIQUÉE AU RENSEIGNEMENT SUR LA MENACE (THREAT INTELLIGENCE)
# LE RENSEIGNEMENT SUR LA MENACE CONSISTE À COLLECTER (TYPIQUEMENT SUR LE WEB OU DARKWEB), UN ENSEMBLE D’INFORMATIONS SUR LA MENACE ET À LES RENDRE OPÉRATIONNELLES : QUELS GROUPES D’ATTAQUANTS SONT ACTIFS ET POUR FAIRE QUOI, AVEC QUELS MODES OPÉRATOIRES, EXPLOITANT QUELLES VULNÉRABILITÉS, À PARTIR DE QUELS SERVEURS WEB COMPROMIS DE COMMAND & CONTROL… PLUTÔT QUE DE SE BATTRE CONTRE UN ENNEMI INVISIBLE, IL S’AGIT D’OBTENIR DES RENSEIGNEMENTS SUR LUI POUR MIEUX LE CONTRER. UN DES PROBLÈMES DU RENSEIGNEMENT SUR LA MENACE RÉSIDE DANS LA CAPACITÉ À FOURNIR DES INFORMATIONS PERTINENTES DE MANIÈRE STRUCTURÉE.
# 7- L’IA APPLIQUÉE À LA GESTION DES VULNÉRABILITÉS
# LA GESTION DES VULNÉRABILITÉS EST DEVENUE UN POINT DE TENSION POUR LES ÉQUIPES OPÉRATIONNELLES, DU FAIT DE L’AUGMENTATION CONSTANTE DU NOMBRE DE FAILLES CONNUES, DES DIFFICULTÉS À ÉVALUER LES RISQUES RÉELS INDUITS ET À PRIORISER ET AUTOMATISER LE DÉPLOIEMENT DES PATCHS. EN EFFET, SUR LES MILLIERS DE VULNÉRABILITÉS PUBLIÉES TOUS LES ANS, SEULE UNE FRACTION EST RÉELLEMENT UTILISÉE PAR LES ATTAQUANTS. DE PLUS, CERTAINS SYSTÈMES EN SONT PROTÉGÉS PAR DES DÉFENSES PÉRIMÉTRIQUES.
# CETTE COMPLEXITÉ INCITE LES FOURNISSEURS D’OUTILS DE GESTION DES VULNÉRABILITÉS À INTÉGRER DES TECHNOLOGIES D’IA DANS LEURS SOLUTIONS. L’OBJECTIF DE L’IA APPLIQUÉE À LA GESTION DES VULNÉRABILITÉS EST D’AMÉLIORER LA DÉCOUVERTE DES ÉQUIPEMENTS DÉPLOYÉS, LE SCAN DES VULNÉRABILITÉS, LA DÉTERMINATION DES RISQUES ASSOCIÉS EN LIEN AVEC L’INTELLIGENCE SUR LA MENACE, LA PRIORISATION ET LE DÉPLOIEMENT DES PATCHS.
# 8- L’IA APPLIQUÉE AUX TESTS D’INTRUSIONS
# DANS LA MÊME VEINE, ET BIEN QU’IL S’AGISSE À CE STADE PLUS D’UNE VISION OU DE PROTOTYPES QUE DE RÉALITÉ, DES TRAVAUX ÉMANANT DE LABORATOIRES UNIVERSITAIRES, D’AGENCES GOUVERNEMENTALES, D’ENTREPRISES ÉTABLIES OU DE START-UPS, VISENT À APPLIQUER L’IA AUX TESTS D’INTRUSIONS.
# CES TESTS NÉCESSITENT DE TROUVER DES VULNÉRABILITÉS PARMI DE MULTIPLES POSSIBLES SUR DE NOMBREUX SYSTÈMES, PUIS D’EXPLOITER CES VULNÉRABILITÉS PAR DIFFÉRENTES TECHNIQUES. L’ARBRE DES CHOIX POSSIBLES DEVIENT RAPIDEMENT TROP IMPORTANT POUR ÊTRE GÉRÉ PAR UN HUMAIN OU MÊME PARCOURU AUTOMATIQUEMENT. PAR AILLEURS, L’ANALYSE DE LA PRATIQUE DES TESTEURS HUMAINS RÉVÈLE QU’ILS ONT TENDANCE À PRIVILÉGIER LE PARCOURS DE L’ARBRE EN PROFONDEUR PLUTÔT QU’EN LARGEUR. SI TECHNOLOGIES D’IA CONSTITUENT UN MOYEN DE COMPENSER LES LIMITES ET CONTRAINTES DES DISPOSITIFS ACTUELS, PLUSIEURS POINTS D’ATTENTION DOIVENT ÊTRE PRIS EN COMPTE. L’IA OU PLUTÔT LE MACHINE LEARNING A SURTOUT FAIT SES PREUVES DANS LA DÉTECTION DE FRAUDES, UN DOMAINE CONNEXE À LA CYBERSÉCURITÉ. SES BONS RÉSULTATS S’EXPLIQUENT PAR LE FAIT QUE L’ON TRAVAILLE DEPUIS UN CERTAIN TEMPS SUR DES DONNÉES NORMÉES. AUSSI, ELLE NE PEUT ÊTRE VUE QUE COMME UN COMPLÉMENT ALGORITHMIQUE AUX OUTILS EXISTANTS.SI L’IA MODIFIE LE NIVEAU D’EXPERTISE NÉCESSAIRE À CERTAINES ACTIVITÉS DE CYBERSÉCURITÉ GRÂCE L’AUTOMATISATION DES TÂCHES À FAIBLE VALEUR AJOUTÉE, IL N’EN RESTE PAS MOINS QUE POUR LE MOMENT L’IA NE DIMINUE PAS LE BESOIN GLOBAL D’EXPERTISE HUMAINE. EN EFFET LES ÉQUIPES DOIVENT ANALYSER PLUS D’ÉVÈNEMENTS ET DE COMPORTEMENTS SUSPECTS À PARTIR DE REMONTÉES QUI DIFFICILES À INTERPRÉTER ET QUI NÉCESSITENT PAR CONSÉQUENT DES EXPERTISES DE HAUT NIVEAU. L’IA CONNAÎT ÉGALEMENT CERTAINES LIMITES MORALES VOIRE LÉGALES CAR ELLE PEUT PARFOIS PRENDRE DES DÉCISIONS DISCUTABLES D’UN POINT DE VUE ÉTHIQUE ET EXPLOITE SOUVENT DES DONNÉES À CARACTÈRE PERSONNEL.
# ET SURTOUT… LES SYSTÈMES DE DÉFENSE À BASE D’IA SONT EUX-MÊMES VULNÉRABLES AUX LEURRES QUE LES ATTAQUANTS METTENT EN PLACE POUR LES CONTOURNER.
# LES ATTAQUANTS UTILISENT AUSSI DES TECHNOLOGIES D’IA POUR AUGMENTER LEUR POTENTIEL DE NUISANCE À MOINDRE COÛT : POUR SÉLECTIONNER LEURS CIBLES, OPTIMISER LEURS CAPACITÉS D’INTRUSION (EX : PHISHING INTELLIGENT), DÉTERMINER LES MEILLEURES FAILLES À EXPLOITER (EX : SCAN DE PAGES WEB INTELLIGENT), PASSER AUTANT QUE POSSIBLE SOUS LE RADAR DES SYSTÈMES DE DÉTECTION, ETC. PAR SA CAPACITÉ À TRAITER DE GRANDS VOLUMES DE DONNÉES, L’IA PEUT ÊTRE VUE COMME UN ALLIÉ AU SERVICE DES DÉFENSEURS DU CYBERESPACE, EN PARTICULIER POUR DÉTECTER DES MENACES INCONNUES À CONDITION TOUTEFOIS D’ÊTRE EN CAPACITÉ DE TRAITER LES FAUX POSITIFS (ET LES FAUX NÉGATIFS ?). MAIS ELLE PEUT AUSSI ÊTRE MISE À PROFIT PAR LES ASSAILLANTS ET LEUR PERMETTRE DE DÉVELOPPER DES ATTAQUES INTELLIGENTES CAPABLES DE S’ADAPTER EN TEMPS RÉEL AUX RÉACTIONS DÉFENSIVES.
# LA BLOCKCHAIN, L’IA OU LE MACHINE LEARNING SERONT-ILS LES RÉPONSES QUE NOUS ATTENDONS TANT ?
# LÀ ENCORE, IL FAUT FAIRE LA PART DES CHOSES. CES TECHNOLOGIES NE SERONT JAMAIS DES RÉPONSES AUX QUESTIONS QU’ELLES N’ADRESSENT PAS. ELLES PERMETTRONT VRAISEMBLABLEMENT DE FAIRE AVANCER LES DOMAINES DE RECHERCHE, DE CRÉER DE NOUVELLES OFFRES, D’OFFRIR UNE ASSISTANCE AUX PARTIES PRENANTES, MAIS AURONT ENCORE BIEN DES DIFFICULTÉS À SÉCURISER CE QUE NOUS NE MAÎTRISONS PAS TOUJOURS.
